# %% [markdown]
# # **Histogram**
#
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.
#
# Example: Say you ask for the height of 250 people, you might end up with a histogram like this:

# %% [markdown]
# ![Screenshot 2024-11-22 161243.png](data:image/png;base64,...)
#
#
# You can read from the histogram that there are approximately:
#
# 2 people from 140 to 145cm
#
# 5 people from 145 to 150cm
#
# 15 people from 151 to 156cm
#
# 31 people from 157 to 162cm
#
# 46 people from 163 to 168cm
#
# 53 people from 168 to 173cm
#
# 45 people from 173 to 178cm
#
# 28 people from 179 to 184cm
#
# 21 people from 185 to 190cm
#
# 4 people from 190 to 195cm

# %% [markdown]
# # **Create Histogram**
#
# In Matplotlib, we use the hist() function to create histograms.
#
# The hist() function will use an array of numbers to create a histogram, the array is sent into the function as an argument.
#
# For simplicity we use NumPy to randomly generate an array with 250 values, where the values will concentrate around 170, and the standard deviation is 10. Learn more about Normal Data Distribution in our Machine Learning Tutorial.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10,200)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x,edgecolor="black")
plt.show()

# %% [markdown]
# plt.hist(x,bins=None,range=None,density=False,cumulative=False,bottom=None,histtype="bar",align="mid",orientation="vertical",rwidth=None,log=False,color=

# %% [markdown]
# ## **bins**

# %%
# bins
data=[1,12,6,21,22,15,16,20,21,24]
plt.hist(data,bins=4,edgecolor="black")
plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")
plt.show()

# %%
data=[1,12,6,21,22,20,21,24]
plt.hist(data,bins=[1,5,10,20,30],edgecolor="black")
plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")
plt.show()

# %% [markdown]
# ## **range**

# %%
data=[1,12,6,21,22,20,21,24]
plt.hist(data,bins=3,range=(1,30),edgecolor="black")
plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")
plt.show()

# %%
data=[1,12,6,21,22,20,21,24]

plt.hist(data,bins=3,range=(1,24),edgecolor="black")

plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")

plt.show()

# %% [markdown]
# ## **density**

# %% [markdown]
# ![Screenshot 2024-11-25 111420.png](data:image/png;base64,...)

# %%
data=[1,12,6,21,22,20,21,24]
plt.hist(data,bins=4,density=False,ec="black")
plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")
plt.show()

# %%
data=[1,12,6,21,22,20,21,24]
plt.hist(data,bins=4,density=True,ec="black")
plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")
plt.show()

# %%
binwidth =23/4
binwidth
# Out:
# 5.75

# %%
bin_density=2/(8*5.75)
bin_density
# Out:
# 0.043478260869565216

# %% [markdown]
# ## **cumulative**

# %%
data=[1,12,6,21,22,20,21,24]

plt.hist(data,bins=4,range=(1,24),cumulative=True,ec="black")

plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")

plt.show()

# %%
import matplotlib.pyplot as plt

data=[1,12,6,21,22,20,21,24]
y=[1,11,21,31]

plt.hist(data,bins=y,range=(1,24),bottom=[1,3,5],ec="black")

plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")

plt.show()

# %% [markdown]
# ## **bottom**

# %% [markdown]
# ## **histtype**

# %%
import matplotlib.pyplot as plt

data=[1,12,6,21,22,20,21,24]
y=[1,11,21,31]

plt.hist(data,bins=y,histtype="step",ec="black")

plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")

plt.xticks(y)

plt.show()

# %%
import matplotlib.pyplot as plt

data=[1,12,6,21,22,20,21,24]
y=[1,11,21,31]

plt.hist(data,bins=y,histtype="stepfilled",ec="black")

plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")

plt.xticks(y)

plt.show()

# %% [markdown]
# # **align**

# %%
import matplotlib.pyplot as plt

data=[1,12,6,21,22,20,21,24]
y=[1,11,21,31]

plt.hist(data,bins=y,align="left",ec="black")

plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")

plt.xticks(y)

plt.show()

# %%
import matplotlib.pyplot as plt

data=[1,12,6,21,22,20,21,24]
y=[1,11,21,31]

plt.hist(data,bins=y,align="right",ec="black")

plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")

plt.xticks(y)

plt.show()

# %% [markdown]
# ## **orientation**

# %%
import matplotlib.pyplot as plt

data=[1,12,6,21,22,20,21,24]
y=[1,11,21,31]

plt.hist(data,bins=y,orientation="horizontal",ec="black")


plt.title("histogram of data")

plt.xticks(y)

plt.show()

# %% [markdown]
# ##**rwidth**

# %%
import matplotlib.pyplot as plt

data=[1,12,6,21,22,20,21,24]
y=[1,11,21,31]

plt.hist(data,bins=y,rwidth=0.5,ec="black") # rwidth : 0 to 1

plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")

plt.xticks(y)

plt.show()

# %%
import matplotlib.pyplot as plt

data=[1,12,6,21,22,20,21,24]
y=[1,11,21,31]

plt.hist(data,bins=y,log=True,ec="black") # rwidth : 0 to 1

plt.xlabel("value")
plt.ylabel("frequency")
plt.title("histogram of data")

plt.xticks(y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

data=np.random.randn(1000)


sns.histplot(data,bins=30,kde=True,color="lightblue",edgecolor="red")

plt.xlabel("value")
plt.ylabel("density")
plt.title("customized histogram with density plot")

plt.show()
